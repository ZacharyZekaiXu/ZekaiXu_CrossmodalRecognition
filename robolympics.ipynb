# %% [markdown]
# <a href="https://colab.research.google.com/github/ZacharyZekaiXu/ZekaiXu_CrossmodalRecognition/blob/main/robolympics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Zekai Xu

# %% [markdown]
# ---
# # Objective
#
# This notebook provides a minimal but complete example of the reinforcement learning infrastructure, training sequence, and result visualization. We will use a [pybullet](https://github.com/bulletphysics/bullet3) locomotion environment and [dm-acme](https://github.com/deepmind/acme) reinforcement learning agents to learn a policy to perform a simple task with the 2D `Hopper` robot.
#
# We will show how to create and inspect the environment and how to start modifying it to have robots perform various tasks. This example should provide a good starting point for your own exploration!
#
# Even though this example uses a very simple robot, you can start experimenting with more complicated ones, such as `Ant` and `Humanoid` by just importing and modifying them as shown in this example. Also, start exploring the source code of the environments so you can modify them more easily later.
#
# We would also suggest going over the `dm-acme` tutorial notebook:
#
# https://github.com/deepmind/acme/blob/master/examples/tutorial.ipynb
#
# For a general introduction to Reinforcement Learning, it's worth checking out this course:
#
# https://deepmind.com/learning-resources/-introduction-reinforcement-learning-david-silver

# %% [markdown]
# # Colab limits
#
# Please note that due to the Colab usage limits on the one hand, and the compute requirements of the project on the other hand, most likely you won't be able to leverage Colab's GPU for a sufficient amount of time. Instead, we suggest working in CPU-only mode (it shouldn't slow you down very much, typical RL workloads are CPU-bound anyway). Make sure you're not using GPU by doing Runtime -> Change runtime type -> Hardware accelerator -> None.
#
# Also, when instantiating the environments, make sure to keep the default setting `render=False`.

# %% [markdown]
# ---
# # Setup

# %%
# @title Install dependencies
# @markdown In the first cell we'll install all of the necessary dependencies.
# !sudo apt-get update > /dev/null 2>&1
# !sudo apt-get -y install ffmpeg freeglut3-dev xvfb > /dev/null 2>&1  # For visualization.

# !pip install dm-sonnet --quiet
# !pip install imageio-ffmpeg --quiet
# !pip install pybullet --quiet
# !pip install dm-acme[jax,tensorflow] --quiet
# !pip install trfl --quiet
# Out:
#      |████████████████████████████████| 254 kB 8.6 MB/s
#      |████████████████████████████████| 26.9 MB 1.2 MB/s
#      |████████████████████████████████| 91.7 MB 30 kB/s
#      |████████████████████████████████| 314 kB 1.3 MB/s
# WARNING: dm-acme 0.4.0 does not provide the extra 'tensorflow'
#      |████████████████████████████████| 3.8 MB 21.4 MB/s
#      |████████████████████████████████| 72 kB 614 kB/s
#      |████████████████████████████████| 342 kB 65.3 MB/s
#      |████████████████████████████████| 197 kB 72.5 MB/s
#      |████████████████████████████████| 145 kB 75.1 MB/s
#      |████████████████████████████████| 117 kB 75.1 MB/s
#      |████████████████████████████████| 6.4 MB 69.0 MB/s
#      |████████████████████████████████| 4.0 MB 80.4 MB/s
#      |████████████████████████████████| 668.3 MB 19 kB/s
#      |████████████████████████████████| 5.7 MB 75.0 MB/s
#      |████████████████████████████████| 462 kB 10.1 MB/s
#      |████████████████████████████████| 596 kB 15.3 MB/s
#      |████████████████████████████████| 217 kB 10.1 MB/s
#      |████████████████████████████████| 51 kB 6.4 MB/s
#      |████████████████████████████████| 272 kB 10.6 MB/s
#   Building wheel for dm-acme (setup.py) ... done
#      |████████████████████████████████| 104 kB 874 kB/s

# %%
# Imports
import os
import shutil
import matplotlib
import pybullet_envs

from acme.utils import loggers
from acme.tf import networks
from acme.tf import utils as tf2_utils
from acme.agents.tf.d4pg import D4PG
from acme.agents.tf.ddpg import DDPG
from acme.agents.tf.dmpo import DistributionalMPO
from acme import wrappers, specs, environment_loop

import numpy as np
import sonnet as snt
import matplotlib.pyplot as plt
import matplotlib.animation as animation

from google.colab import drive
from IPython.display import HTML

# %%
# @title Import `pybullet` locomotion environments

from pybullet_envs.gym_locomotion_envs import HopperBulletEnv
from pybullet_envs.gym_locomotion_envs import Walker2DBulletEnv
from pybullet_envs.gym_locomotion_envs import HalfCheetahBulletEnv
from pybullet_envs.gym_locomotion_envs import AntBulletEnv
from pybullet_envs.gym_locomotion_envs import HumanoidBulletEnv

# %%
# @title Figure settings
import ipywidgets as widgets       # interactive display
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.style.use("https://raw.githubusercontent.com/NeuromatchAcademy/content-creation/main/nma.mplstyle")

# %% [markdown]
# ---
# # Functions for saving and restoring checkpoints
# Due to Colab usage limits, the Colab runtime will be restarting periodically. In order to preserve the most recent training checkpoint during a restart, please use the functions below.
#
# To do so, you'll have to first mount Google Drive (will be shown below).
#
# ### Before runtime restart:
# Use `save_ckpt_to_drive` to locate the checkpoint and save it to your Google Drive in a directory `/acme_ckpt`
#
# ### After runtime restart:
# Use `restore_ckpt_from_drive` to recover the checkpoint from Google Drive and copy it back to the restarted Colab virtual machine.

# %%
def save_ckpt_to_drive(agent):
  """Saves agent checkpoint directory to Google Drive.

  WARNING: Will replace the entire content of the
  drive directory `/root/drive/MyDrive/acme_ckpt`.

  Args:
    agent: core.Actor
  """
  src = agent._learner._checkpointer._checkpoint_manager.directory
  dst = '/root/drive/MyDrive/acme_ckpt'
  if os.path.exists(dst):
    shutil.rmtree(dst)
  shutil.copytree(src, dst)
  print(f'Saved {src} to {dst}')


def restore_ckpt_from_drive(agent):
  """Restores agent checkpoint directory from Google Drive.

  The name of the local checkpoint directory will be different
  than it was when the checkpoint was originally saved.
  This is because `acme` checkpoiner creates a new directory
  upon restart.

  WARNING: Will replace the entire content of the local
  checkpoint directory (if it exists already).

  Args:
    agent: core.Actor
  """
  src = '/root/drive/MyDrive/acme_ckpt'
  dst = agent._learner._checkpointer._checkpoint_manager.directory
  if os.path.exists(dst):
        shutil.rmtree(dst)
  shutil.copytree(src, dst)
  print(f'Restored {dst} from {src}')

# %% [markdown]
# ---
# # Convenience function for creating videos
#
# Use this function to generate videos of your experiments.

# %%
def display_video(frames, framerate=30):
  """Generates video from `frames`.

  Args:
    frames (ndarray): Array of shape (n_frames, height, width, 3).
    framerate (int): Frame rate in units of Hz.

  Returns:
    Display object.
  """
  height, width, _ = frames[0].shape
  dpi = 70
  orig_backend = matplotlib.get_backend()
  matplotlib.use('Agg')  # Switch to headless 'Agg' to inhibit figure rendering.
  fig, ax = plt.subplots(1, 1, figsize=(width / dpi, height / dpi), dpi=dpi)
  matplotlib.use(orig_backend)  # Switch back to the original backend.
  ax.set_axis_off()
  ax.set_aspect('equal')
  ax.set_position([0, 0, 1, 1])
  im = ax.imshow(frames[0])
  def update(frame):
    im.set_data(frame)
    return [im]
  interval = 1000/framerate
  anim = animation.FuncAnimation(fig=fig, func=update, frames=frames,
                                  interval=interval, blit=True, repeat=False)
  return HTML(anim.to_html5_video())

# %% [markdown]
# ---
# # Network factory methods for select continuous control agents
# The functions below initialize and return the policy and critic networks for several continuous control agents (DDPG, D4PG, DMPO) used later in this notebook. Feel free to explore other agents as well. For more information on these and other agents, their implementations, and links to their corresponding papers see
# https://github.com/deepmind/acme/tree/master/acme/agents
#
# Please note that the hyperparameters `layer_sizes`, `vmin`, `vmax`, `num_atoms` are set to reasonable default values, but may reqiure adjustment. Especially, `vmin` and `vmax` should be used with care. Please see, e.g., https://github.com/deepmind/acme/blob/master/acme/agents/tf/d4pg/README.md for more information.

# %%
def make_networks_d4pg(action_spec,
                       policy_layer_sizes=(256, 256, 256),
                       critic_layer_sizes=(512, 512, 256),
                       vmin=-150.,
                       vmax=150.,
                       num_atoms=51,
                      ):
  """Networks for D4PG agent."""
  action_size = np.prod(action_spec.shape, dtype=int)

  policy_network = snt.Sequential([
      tf2_utils.batch_concat,
      networks.LayerNormMLP(layer_sizes=policy_layer_sizes + (action_size,)),
      networks.TanhToSpec(spec=action_spec)
      ])
  critic_network = snt.Sequential([
      networks.CriticMultiplexer(
          action_network=networks.ClipToSpec(action_spec),
          critic_network=networks.LayerNormMLP(
              layer_sizes=critic_layer_sizes,
              activate_final=True),
      ),
      networks.DiscreteValuedHead(vmin=vmin,
                                  vmax=vmax,
                                  num_atoms=num_atoms)
      ])

  return policy_network, critic_network


def make_networks_ddpg(action_spec,
                       policy_layer_sizes=(256, 256, 256),
                       critic_layer_sizes=(512, 512, 256),
                      ):
  """Networks for DDPG agent."""
  action_size = np.prod(action_spec.shape, dtype=int)

  policy_network = snt.Sequential([
      tf2_utils.batch_concat,
      networks.LayerNormMLP(layer_sizes=policy_layer_sizes + (action_size,)),
      networks.TanhToSpec(spec=action_spec)
      ])
  critic_network = networks.CriticMultiplexer(
          action_network=networks.ClipToSpec(action_spec),
          critic_network=networks.LayerNormMLP(
              layer_sizes=critic_layer_sizes + (1,),
              activate_final=False),
              )

  return policy_network, critic_network


def make_networks_dmpo(action_spec,
                       policy_layer_sizes=(256, 256, 256),
                       critic_layer_sizes=(512, 512, 256),
                       vmin=-150.,
                       vmax=150.,
                       num_atoms=51,
                      ):
  """Networks for DMPO agent."""
  action_size = np.prod(action_spec.shape, dtype=int)

  policy_network = snt.Sequential([
      tf2_utils.batch_concat,
      networks.LayerNormMLP(layer_sizes=policy_layer_sizes,
                            activate_final=True),
      networks.MultivariateNormalDiagHead(
          action_size,
          min_scale=1e-6,
          tanh_mean=False,
          init_scale=0.7,
          fixed_scale=False,
          use_tfd_independent=True)
  ])

  # The multiplexer concatenates the (maybe transformed) observations/actions.
  critic_network = networks.CriticMultiplexer(
      action_network=networks.ClipToSpec(action_spec),
      critic_network=networks.LayerNormMLP(layer_sizes=critic_layer_sizes,
                                           activate_final=True),
                                           )
  critic_network = snt.Sequential([
                                   critic_network,
                                   networks.DiscreteValuedHead(vmin=vmin,
                                                               vmax=vmax,
                                                               num_atoms=num_atoms)
                                   ])

  return policy_network, critic_network

# %% [markdown]
# ---
# # List of all `pybullet` environments
#
# You can print the full list of environments by running the cell below. Only a subset of them are locomotion environments but feel free to explore the other ones if you're interested.

# %%
pybullet_envs.getList()
# Out:
# ['- HumanoidDeepMimicBackflipBulletEnv-v1',
#  '- HumanoidDeepMimicWalkBulletEnv-v1',
#  '- CartPoleBulletEnv-v1',
#  '- CartPoleContinuousBulletEnv-v0',
#  '- MinitaurBulletEnv-v0',
#  '- MinitaurBulletDuckEnv-v0',
#  '- RacecarBulletEnv-v0',
#  '- RacecarZedBulletEnv-v0',
#  '- KukaBulletEnv-v0',
#  '- KukaCamBulletEnv-v0',
#  '- InvertedPendulumBulletEnv-v0',
#  '- InvertedDoublePendulumBulletEnv-v0',
#  '- InvertedPendulumSwingupBulletEnv-v0',
#  '- ReacherBulletEnv-v0',
#  '- PusherBulletEnv-v0',
#  '- ThrowerBulletEnv-v0',
#  '- Walker2DBulletEnv-v0',
#  '- HalfCheetahBulletEnv-v0',
#  '- AntBulletEnv-v0',
#  '- HopperBulletEnv-v0',
#  '- HumanoidBulletEnv-v0',
#  '- HumanoidFlagrunBulletEnv-v0',
#  '- HumanoidFlagrunHarderBulletEnv-v0',
#  '- MinitaurExtendedEnv-v0',
#  '- MinitaurReactiveEnv-v0',
#  '- MinitaurBallGymEnv-v0',
#  '- MinitaurTrottingEnv-v0',
#  '- MinitaurStandGymEnv-v0',
#  '- MinitaurAlternatingLegsEnv-v0',
#  '- MinitaurFourLegStandEnv-v0',
#  '- KukaDiverseObjectGrasping-v0']

# %% [markdown]
# ---
# # Modifying the environment base class
#
# You may start your exploration of the `pybullet` locomotion environment code from this entry point, going up and down the hierarchy of classes:
#
# https://github.com/bulletphysics/bullet3/blob/master/examples/pybullet/gym/pybullet_envs/gym_locomotion_envs.py
#
# For our experiments, we will be using the `pybullet` locomotion environments with several different robots (`Hopper`, `Ant`, `Humanoid`, etc.). In order to have the robots perform different tasks, we'll need to modify some parts of the environments' code. This will (mainly) amount to modifying the environments' reward calculation in the `step` method.
#
# In the cell below we provide a minimal example modifying the `HopperBulletEnv` environment class. Normally, to create a Hopper environment you would just create an instance of the HopperBulletEnv class:
#
# ```
# env = HopperBulletEnv()
# ```
# However, if you analyze the environment's code, you'll realize that making changes (such as modifying the reward calculation) is difficult in this way. Instead, it's useful to create a custom child class inheriting from the original `HopperBulletEnv` class and override some of its methods. This subclassing will allow you to easily access the interesting pieces of the environment class to modify.
#
# In the example of a custom `Hopper` class below, we override several methods of its parent class to (i) make the reward calculation modifiable, (ii) add `step_counter` to enforce fixed episode duration, and (iii) make the episode termination conditions modifiable. Please note that in some cases the overriding methods still call their parent methods after executing the required modifications (such as the `__init__`, `reset`, `_isDone` methods do.). In contrast, the `step` method is overriden in its entirety and doesn't reference its parent method. So instead of the code line above, the environment would be created as:
# ```python
# env = Hopper()
# ```
# You can use this approach and this example as the starting point of your project. In many cases, this custom class can be used as is (with only a name change) with other robots in the `pybullet` locomotion environments by inheriting from their respective original environment classes instead of from `HopperBulletEnv`.

# %%
class Ant(AntBulletEnv):

  def __init__(self, render=False, episode_steps=1000):
    """Modifies `__init__` in `HopperBulletEnv` parent class."""
    self.episode_steps = episode_steps
    super().__init__(render=render)

  def reset(self):
    """Modifies `reset` in `WalkerBaseBulletEnv` base class."""
    self.step_counter = 0
    return super().reset()

  def _isDone(self):
    """Modifies `_isDone` in `WalkerBaseBulletEnv` base class."""
    return (self.step_counter == self.episode_steps
            or super()._isDone())

  def step(self, a):
    """Fully overrides `step` in `WalkerBaseBulletEnv` base class."""

    self.step_counter += 1

    # if multiplayer, action first applied to all robots,
    # then global step() called, then _step() for all robots
    # with the same actions
    if not self.scene.multiplayer:
      self.robot.apply_action(a)
      self.scene.global_step()

    state = self.robot.calc_state()  # also calculates self.joints_at_limit

    # state[0] is body height above ground, body_rpy[1] is pitch
    self._alive = float(self.robot.alive_bonus(state[0] + self.robot.initial_z,
                                               self.robot.body_rpy[1]))
    done = self._isDone()
    if not np.isfinite(state).all():
      print("~INF~", state)
      done = True

    potential_old = self.potential
    self.potential = self.robot.calc_potential()
    progress = float(self.potential - potential_old)

    feet_collision_cost = 0.0
    for i, f in enumerate(self.robot.feet):
      contact_ids = set((x[2], x[4]) for x in f.contact_list())
      if (self.ground_ids & contact_ids):
        self.robot.feet_contact[i] = 1.0
      else:
        self.robot.feet_contact[i] = 0.0

    # let's assume we have DC motor with controller, and reverse current braking
    electricity_cost = self.electricity_cost * float(
        np.abs(a * self.robot.joint_speeds).mean())
    electricity_cost += self.stall_torque_cost * float(np.square(a).mean())

    joints_at_limit_cost = float(self.joints_at_limit_cost * self.robot.joints_at_limit)

    self.rewards = [
                    self._alive, progress, electricity_cost,
                    joints_at_limit_cost, feet_collision_cost
                    ]
    self.HUD(state, a, done)
    self.reward += sum(self.rewards)

    return state, sum(self.rewards), bool(done), {}

# %% [markdown]
# ---
# # Instantiate the environment
#
# Here, we are creating an example `Hopper` environment. Once created, we are wrapping it with `GymWrapper` to make the native `Gym` environment interface compatible with the one used in the `dm-acme` library, which is the reinforcement learning package that we will be using. `dm-acme` adheres to the interface defined here: https://github.com/deepmind/dm_env. Finally, we also use `SinglePrecisionWrapper` to enforce single-precision on a potentially double-precision environment.

# %%
env = Ant(render=False)

env = wrappers.GymWrapper(env)
env = wrappers.SinglePrecisionWrapper(env)

action_spec = env.action_spec()  # Specifies action shape and dimensions.
env_spec = specs.make_environment_spec(env)  # Environment specifications.

# %% [markdown]
# ---
# # The default task

# %% [markdown]
# If not modified, the default task of the `HopperBulletEnv` environment is to have the robot hop to the target location located 1 km away. The target location is stored as an attribute of the `robot` object and can be accessed as in the cell below.
#
# The task also contains other constraints, such as `electricity_cost`, and certain episode termination conditions. Please start from our custom `Hopper` class in the above cell and work your way backwards to the the environment code for more details!

# %%
# x and y coordinates of the target location.
env.robot.walk_target_x, env.robot.walk_target_y
# Out:
# (1000.0, 0)

# %% [markdown]
# ---
# # Let's inspect the environment a bit
#
# #### Plot one frame of the environment

# %%
_ = env.reset()

frame = env.environment.render(mode='rgb_array')
plt.imshow(frame)
plt.axis('off')
plt.show()

# %% [markdown]
# ## Run the environment with random actions
#
# We haven't trained the policy yet, but we can still see the environment in action by passing a random control sequence to it.

# %%
# Run env for n_steps, apply random actions, and show video.
n_steps = 200

frames = []
timestep = env.reset()
for _ in range(n_steps):
  # Random control of actuators.
  action = np.random.uniform(action_spec.minimum,
                             action_spec.maximum,
                             size=action_spec.shape)
  timestep = env.step(action)
  frames.append(env.environment.render(mode='rgb_array'))

display_video(frames, framerate=20)
# Out:
# <video width="320" height="240" controls autoplay>
#   <source type="video/mp4" src="...

# %% [markdown]
# ## Lets take a look at some other environment properties
#
# Notice the shapes and min/max limits

# %%
print('Actions:\n', env_spec.actions)
print('Observations:\n', env_spec.observations)
print('Rewards:\n', env_spec.rewards)
# Out:
# Actions:
#  BoundedArray(shape=(8,), dtype=dtype('float32'), name='action', minimum=[-1. -1. -1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1. 1. 1.])
# Observations:
#  BoundedArray(shape=(28,), dtype=dtype('float32'), name='observation', minimum=[-inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf
#  -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf], maximum=[inf inf inf inf inf inf inf inf inf inf inf inf inf inf inf inf inf inf
#  inf inf inf inf inf inf inf inf inf inf])
# Rewards:
#  Array(shape=(), dtype=dtype('float32'), name='reward')

# %% [markdown]
# ## Inspect some of the robot properties
#
# Let's examine the (Cartesian) coordinates of different body parts of the robot and its speed. Notice that `robot` is an attribute of the `env` class. Also, note how the body parts are accessed as you may need it for adjusting the reward calculation in your project.
#
# Feel free to explore other properties (attributes) of the `env.robot` object, such as velocities, joint angles, etc.

# %%
# Cartesian coordinates of body parts.
for body_part in env.robot.parts.keys():
  print(f"{body_part:10} {env.robot.parts[body_part].pose().xyz()}")
# Out:
# front_left_leg [ 0.13645507 -0.08835128  0.36145595]
# torso      [ 0.00469496 -0.13924362  0.36151908]
# link0_3    [ 0.26834243 -0.03730498  0.3614489 ]
# aux_1      [0.33608493 0.08683588 0.36148857]
# link0_5    [0.40382742 0.21097675 0.36152824]
# front_left_foot [0.52129377 0.42635881 0.22077233]
# front_right_leg [-0.04647858 -0.00751024  0.36153278]
# link0_8    [-0.09752487  0.12437711  0.36160256]
# aux_2      [-0.20705268  0.21384026  0.36166672]
# link0_10   [-0.31658049  0.30330341  0.36173087]
# front_right_foot [-0.50654643  0.45850549  0.22092868]
# left_back_leg [-0.12731965 -0.19044388  0.36147006]
# link0_13   [-0.25920701 -0.24149018  0.36147711]
# aux_3      [-0.39167974 -0.29099752  0.36148497]
# link0_15   [-0.52415247 -0.34050485  0.36149284]
# left_back_foot [-0.75401157 -0.42633311  0.22078639]
# right_back_leg [ 0.055614   -0.27128493  0.36139322]
# link0_18   [ 0.1066603  -0.40317227  0.36132345]
# aux_4      [ 0.22279668 -0.48387132  0.36126168]
# link0_20   [ 0.33893307 -0.56457037  0.36119991]
# right_back_foot [ 0.54054585 -0.70462376  0.22071028]
# floor      [0. 0. 0.]

# %%
# Cartesian components of robot speed.
env.robot_body.speed()
# Out:
# array([0.03084697, 0.03732419, 0.01359536])

# %% [markdown]
# ---
# # Create the `dm-acme` agent
#
# Now we are ready to create the agent. Below we provide examples of creating instances of three select agents (DDPG, D4PG, DMPO) that we implemented above. Please feel free to explore other agents as well. For more information on these and other agents, their implementations, and links to their corresponding papers see
# https://github.com/deepmind/acme/tree/master/acme/agents
#
# The direct links to the implementation of these three agents for you to start exploring are:
#
# https://github.com/deepmind/acme/blob/master/acme/agents/tf/ddpg/agent.py
#
# https://github.com/deepmind/acme/blob/master/acme/agents/tf/d4pg/agent.py
#
# https://github.com/deepmind/acme/blob/master/acme/agents/tf/dmpo/agent.py

# %% [markdown]
# First, lets configure loggers and optimizers:

# %%
learner_log_every = 60.  # Learner logging frequency, seconds.
loop_log_every = 60.  # Environment loop logging frequency, seconds.
checkpoint = True  # Checkpoint saved every 10 minutes.

learner_logger = loggers.TerminalLogger(label='Learner',
                                        time_delta=learner_log_every,
                                        print_fn=print)
loop_logger = loggers.TerminalLogger(label='Environment Loop',
                                     time_delta=loop_log_every,
                                     print_fn=print)

# Note: optimizers can be passed only to the D4PG and DMPO agents.
# The optimizer for DDPG is hard-coded in the agent class.
policy_optimizer = snt.optimizers.Adam(1e-4)
critic_optimizer = snt.optimizers.Adam(1e-4)

# %% [markdown]
# ---
# # D4PG agent

# %% [markdown]
# As an example, in the next cell we instantiate the D4PG agent. Examples of other agents (DDPG, DMPO) are provided at the end of the notebook.

# %%
# Create networks.
policy_network, critic_network = make_networks_d4pg(action_spec)

# Create agent.
agent = D4PG(environment_spec=env_spec,
             policy_network=policy_network,
             critic_network=critic_network,
             observation_network=tf2_utils.batch_concat, # Identity Op.
             policy_optimizer=policy_optimizer,
             critic_optimizer=critic_optimizer,
             logger=learner_logger,
             checkpoint=checkpoint)

# %% [markdown]
# ---
# # Training
#
# Finally, we are ready to start training!
#
# Please refer to the source code to see how to use the environment loop:
#
# https://github.com/deepmind/acme/blob/master/acme/environment_loop.py
#
# The training checkpoint (containing the network weights, optimizer parameters, etc.) will be saved every 10 minutes. Please remember to save and then restore the checkpoint from Google Drive if you are restarting the Colab runtime. See example below.

# %% [markdown]
# *Note:* `num_steps = 100_000` but we reduce it to 1000 to reduce computational time. Please change it back if you want to see the original output of the model.

# %%
num_steps = 1000000 # 100_000  # Number of environment loop steps. Adjust as needed!

loop = environment_loop.EnvironmentLoop(env, agent, logger=loop_logger)

# Start training!
loop.run(num_episodes=None,
         num_steps=num_steps)
# Out:
# [Learner] Critic Loss = 3.504 | Policy Loss = 0.288 | Steps = 1158 | Walltime = 195.681
# [Environment Loop] Episode Length = 1000 | Episode Return = 320.2079162597656 | Episodes = 1 | Steps = 1000 | Steps Per Second = 97.038
# [Learner] Critic Loss = 3.373 | Policy Loss = 0.167 | Steps = 1848 | Walltime = 255.681
# [Environment Loop] Episode Length = 1000 | Episode Return = 257.7266540527344 | Episodes = 7 | Steps = 7000 | Steps Per Second = 101.212
# [Learner] Critic Loss = 3.017 | Policy Loss = 0.149 | Steps = 2561 | Walltime = 315.690
# [Environment Loop] Episode Length = 1000 | Episode Return = 379.0785827636719 | Episodes = 13 | Steps = 13000 | Steps Per Second = 89.153
# [Learner] Critic Loss = 2.690 | Policy Loss = 0.237 | Steps = 3259 | Walltime = 375.726
# [Environment Loop] Episode Length = 1000 | Episode Return = 391.5352478027344 | Episodes = 20 | Steps = 19372 | Steps Per Second = 91.093
# [Learner] Critic Loss = 2.451 | Policy Loss = 0.236 | Steps = 3918 | Walltime = 435.794
# [Environment Loop] Episode Length = 1000 | Episode Return = 323.6618347167969 | Episodes = 28 | Steps = 25414 | Steps Per Second = 89.254
# [Learner] Critic Loss = 2.287 | Policy Loss = 0.290 | Steps = 4601 | Walltime = 495.876
# [Environment Loop] Episode Length = 1000 | Episode Return = 365.7096252441406 | Episodes = 34 | Steps = 31414 | Steps Per Second = 91.680
# [Learner] Critic Loss = 2.260 | Policy Loss = 0.328 | Steps = 5299 | Walltime = 555.931
# [Environment Loop] Episode Length = 1000 | Episode Return = 468.69586181640625 | Episodes = 40 | Steps = 37414 | Steps Per Second = 92.013
# [Learner] Critic Loss = 2.214 | Policy Loss = 0.355 | Steps = 5993 | Walltime = 615.966
# [Environment Loop] Episode Length = 1000 | Episode Return = 484.8987121582031 | Episodes = 46 | Steps = 43414 | Steps Per Second = 97.482
# [Learner] Critic Loss = 2.186 | Policy Loss = 0.376 | Steps = 6664 | Walltime = 676.033
# [Environment Loop] Episode Length = 1000 | Episode Return = 449.5378112792969 | Episodes = 52 | Steps = 49414 | Steps Per Second = 97.415
# [Learner] Critic Loss = 2.121 | Policy Loss = 0.404 | Steps = 7392 | Walltime = 736.094
# [Environment Loop] Episode Length = 1000 | Episode Return = 569.2286376953125 | Episodes = 58 | Steps = 55414 | Steps Per Second = 95.144
# [Learner] Critic Loss = 2.012 | Policy Loss = 0.415 | Steps = 8131 | Walltime = 796.137
# [Environment Loop] Episode Length = 1000 | Episode Return = 598.0038452148438 | Episodes = 64 | Steps = 61414 | Steps Per Second = 96.714
# [Learner] Critic Loss = 2.087 | Policy Loss = 0.408 | Steps = 8849 | Walltime = 856.189
# [Learner] Critic Loss = 2.050 | Policy Loss = 0.440 | Steps = 9568 | Walltime = 916.233
# [Environment Loop] Episode Length = 1000 | Episode Return = 681.9898071289062 | Episodes = 70 | Steps = 67414 | Steps Per Second = 94.986
# [Learner] Critic Loss = 2.066 | Policy Loss = 0.409 | Steps = 10308 | Walltime = 976.236
# [Environment Loop] Episode Length = 1000 | Episode Return = 694.1029052734375 | Episodes = 76 | Steps = 73414 | Steps Per Second = 102.961
# [Learner] Critic Loss = 2.077 | Policy Loss = 0.442 | Steps = 11060 | Walltime = 1036.244
# [Environment Loop] Episode Length = 1000 | Episode Return = 737.2003173828125 | Episodes = 83 | Steps = 80414 | Steps Per Second = 103.741
# [Learner] Critic Loss = 2.078 | Policy Loss = 0.419 | Steps = 11782 | Walltime = 1096.317
# [Environment Loop] Episode Length = 1000 | Episode Return = 590.5451049804688 | Episodes = 89 | Steps = 86414 | Steps Per Second = 95.122
# [Learner] Critic Loss = 2.079 | Policy Loss = 0.440 | Steps = 12486 | Walltime = 1156.341
# [Environment Loop] Episode Length = 1000 | Episode Return = 799.5548706054688 | Episodes = 95 | Steps = 92414 | Steps Per Second = 86.622
# [Learner] Critic Loss = 2.088 | Policy Loss = 0.466 | Steps = 13055 | Walltime = 1216.434
# [Environment Loop] Episode Length = 1000 | Episode Return = 605.2718505859375 | Episodes = 100 | Steps = 97414 | Steps Per Second = 92.952
# [Learner] Critic Loss = 2.093 | Policy Loss = 0.424 | Steps = 13737 | Walltime = 1276.463
# [Environment Loop] Episode Length = 1000 | Episode Return = 764.902587890625 | Episodes = 106 | Steps = 103414 | Steps Per Second = 95.423
# [Learner] Critic Loss = 2.102 | Policy Loss = 0.459 | Steps = 14454 | Walltime = 1336.532
# [Environment Loop] Episode Length = 1000 | Episode Return = 899.6653442382812 | Episodes = 112 | Steps = 109414 | Steps Per Second = 98.550
# [Learner] Critic Loss = 2.150 | Policy Loss = 0.464 | Steps = 15194 | Walltime = 1396.573
# [Environment Loop] Episode Length = 1000 | Episode Return = 954.4100952148438 | Episodes = 118 | Steps = 115414 | Steps Per Second = 98.528
# [Learner] Critic Loss = 2.156 | Policy Loss = 0.464 | Steps = 15909 | Walltime = 1456.614
# [Environment Loop] Episode Length = 1000 | Episode Return = 868.9464111328125 | Episodes = 124 | Steps = 121414 | Steps Per Second = 99.695
# [Learner] Critic Loss = 2.182 | Policy Loss = 0.473 | Steps = 16643 | Walltime = 1516.651
# [Environment Loop] Episode Length = 1000 | Episode Return = 670.8294677734375 | Episodes = 130 | Steps = 127414 | Steps Per Second = 95.611
# [Learner] Critic Loss = 2.225 | Policy Loss = 0.477 | Steps = 17353 | Walltime = 1576.706
# [Environment Loop] Episode Length = 1000 | Episode Return = 869.9896850585938 | Episodes = 136 | Steps = 133414 | Steps Per Second = 97.602
# [Learner] Critic Loss = 2.219 | Policy Loss = 0.467 | Steps = 18063 | Walltime = 1636.723
# [Environment Loop] Episode Length = 1000 | Episode Return = 975.5660400390625 | Episodes = 143 | Steps = 139589 | Steps Per Second = 98.789
# [Learner] Critic Loss = 2.270 | Policy Loss = 0.487 | Steps = 18809 | Walltime = 1696.780
# [Environment Loop] Episode Length = 1000 | Episode Return = 995.9807739257812 | Episodes = 149 | Steps = 145589 | Steps Per Second = 96.365
# [Learner] Critic Loss = 2.229 | Policy Loss = 0.494 | Steps = 19534 | Walltime = 1756.861
# INFO:tensorflow:Assets written to: /root/acme/766572c8-085b-11ed-9740-0242ac1c0002/snapshots/policy/assets
# INFO:tensorflow:Assets written to: /root/acme/766572c8-085b-11ed-9740-0242ac1c0002/snapshots/policy/assets
# INFO:tensorflow:Assets written to: /root/acme/766572c8-085b-11ed-9740-0242ac1c0002/snapshots/critic/assets
# INFO:tensorflow:Assets written to: /root/acme/766572c8-085b-11ed-9740-0242ac1c0002/snapshots/critic/assets
# [Environment Loop] Episode Length = 1000 | Episode Return = 965.2078857421875 | Episodes = 155 | Steps = 151589 | Steps Per Second = 90.792
# [Learner] Critic Loss = 2.211 | Policy Loss = 0.478 | Steps = 20262 | Walltime = 1816.895
# [Environment Loop] Episode Length = 1000 | Episode Return = 786.7472534179688 | Episodes = 161 | Steps = 157589 | Steps Per Second = 100.603
# [Learner] Critic Loss = 2.226 | Policy Loss = 0.488 | Steps = 21013 | Walltime = 1876.900
# [Environment Loop] Episode Length = 1000 | Episode Return = 945.6559448242188 | Episodes = 167 | Steps = 163589 | Steps Per Second = 82.785
# [Learner] Critic Loss = 2.287 | Policy Loss = 0.487 | Steps = 21715 | Walltime = 1936.991
# [Environment Loop] Episode Length = 1000 | Episode Return = 866.5569458007812 | Episodes = 173 | Steps = 169589 | Steps Per Second = 97.791
# [Learner] Critic Loss = 2.237 | Policy Loss = 0.491 | Steps = 22360 | Walltime = 1997.043
# [Learner] Critic Loss = 2.260 | Policy Loss = 0.497 | Steps = 23101 | Walltime = 2057.113
# [Environment Loop] Episode Length = 1000 | Episode Return = 1246.5565185546875 | Episodes = 179 | Steps = 175589 | Steps Per Second = 102.033
# [Learner] Critic Loss = 2.229 | Policy Loss = 0.491 | Steps = 23864 | Walltime = 2117.145
# [Environment Loop] Episode Length = 1000 | Episode Return = 1231.170654296875 | Episodes = 186 | Steps = 182589 | Steps Per Second = 99.478
# [Learner] Critic Loss = 2.233 | Policy Loss = 0.491 | Steps = 24626 | Walltime = 2177.178
# [Environment Loop] Episode Length = 1000 | Episode Return = 1289.975341796875 | Episodes = 193 | Steps = 189589 | Steps Per Second = 102.778
# [Learner] Critic Loss = 2.206 | Policy Loss = 0.492 | Steps = 25376 | Walltime = 2237.226
# [Environment Loop] Episode Length = 1000 | Episode Return = 1037.14404296875 | Episodes = 200 | Steps = 196589 | Steps Per Second = 100.941
# [Learner] Critic Loss = 2.191 | Policy Loss = 0.490 | Steps = 26140 | Walltime = 2297.297
# [Environment Loop] Episode Length = 1000 | Episode Return = 1183.6431884765625 | Episodes = 207 | Steps = 203589 | Steps Per Second = 100.614
# [Learner] Critic Loss = 2.131 | Policy Loss = 0.482 | Steps = 26906 | Walltime = 2357.328
# [Environment Loop] Episode Length = 1000 | Episode Return = 1303.00146484375 | Episodes = 214 | Steps = 210589 | Steps Per Second = 104.307
# WARNING:tensorflow:5 out of the last 5 calls to <function MultiDeviceSaver.save.<locals>.tf_function_save at 0x7f1b7c648830> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function MultiDeviceSaver.save.<locals>.tf_function_save at 0x7f1b7c648830> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [Learner] Critic Loss = 2.158 | Policy Loss = 0.489 | Steps = 27672 | Walltime = 2417.394
# [Environment Loop] Episode Length = 1000 | Episode Return = 1159.9796142578125 | Episodes = 221 | Steps = 217589 | Steps Per Second = 102.628
# [Learner] Critic Loss = 2.149 | Policy Loss = 0.484 | Steps = 28433 | Walltime = 2477.433
# [Learner] Critic Loss = 2.075 | Policy Loss = 0.478 | Steps = 29212 | Walltime = 2537.504
# [Environment Loop] Episode Length = 1000 | Episode Return = 1350.008544921875 | Episodes = 228 | Steps = 224589 | Steps Per Second = 104.873
# [Learner] Critic Loss = 2.048 | Policy Loss = 0.477 | Steps = 29982 | Walltime = 2597.559
# [Environment Loop] Episode Length = 1000 | Episode Return = 1293.9346923828125 | Episodes = 235 | Steps = 231589 | Steps Per Second = 104.034
# [Learner] Critic Loss = 2.080 | Policy Loss = 0.479 | Steps = 30711 | Walltime = 2657.581
# [Environment Loop] Episode Length = 1000 | Episode Return = 1486.6724853515625 | Episodes = 241 | Steps = 237589 | Steps Per Second = 82.399
# [Learner] Critic Loss = 2.051 | Policy Loss = 0.477 | Steps = 31210 | Walltime = 2717.716
# [Environment Loop] Episode Length = 1000 | Episode Return = 1522.4796142578125 | Episodes = 245 | Steps = 241589 | Steps Per Second = 49.692
# [Learner] Critic Loss = 2.079 | Policy Loss = 0.475 | Steps = 31579 | Walltime = 2777.811
# [Environment Loop] Episode Length = 1000 | Episode Return = 1138.2672119140625 | Episodes = 248 | Steps = 244589 | Steps Per Second = 47.185
# [Learner] Critic Loss = 2.029 | Policy Loss = 0.475 | Steps = 31975 | Walltime = 2837.834
# [Environment Loop] Episode Length = 1000 | Episode Return = 1544.0986328125 | Episodes = 253 | Steps = 249589 | Steps Per Second = 85.939
# [Learner] Critic Loss = 1.988 | Policy Loss = 0.478 | Steps = 32600 | Walltime = 2897.845
# [Environment Loop] Episode Length = 1000 | Episode Return = 1536.8868408203125 | Episodes = 259 | Steps = 255589 | Steps Per Second = 92.690
# [Learner] Critic Loss = 1.895 | Policy Loss = 0.466 | Steps = 33297 | Walltime = 2957.901
# WARNING:tensorflow:6 out of the last 6 calls to <function MultiDeviceSaver.save.<locals>.tf_function_save at 0x7f1b7c648a70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function MultiDeviceSaver.save.<locals>.tf_function_save at 0x7f1b7c648a70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [Environment Loop] Episode Length = 1000 | Episode Return = 1663.60693359375 | Episodes = 265 | Steps = 261589 | Steps Per Second = 96.120
# [Learner] Critic Loss = 1.789 | Policy Loss = 0.444 | Steps = 34015 | Walltime = 3017.937
# [Environment Loop] Episode Length = 1000 | Episode Return = 1515.294677734375 | Episodes = 271 | Steps = 267589 | Steps Per Second = 90.323
# [Learner] Critic Loss = 1.897 | Policy Loss = 0.452 | Steps = 34677 | Walltime = 3077.940
# [Environment Loop] Episode Length = 1000 | Episode Return = 1621.5830078125 | Episodes = 277 | Steps = 273589 | Steps Per Second = 93.548
# [Learner] Critic Loss = 1.721 | Policy Loss = 0.430 | Steps = 35402 | Walltime = 3137.993
# [Environment Loop] Episode Length = 1000 | Episode Return = 1647.0767822265625 | Episodes = 283 | Steps = 279589 | Steps Per Second = 90.680
# [Learner] Critic Loss = 1.775 | Policy Loss = 0.444 | Steps = 36139 | Walltime = 3198.045
# [Environment Loop] Episode Length = 1000 | Episode Return = 1478.00537109375 | Episodes = 289 | Steps = 285589 | Steps Per Second = 100.016
# [Learner] Critic Loss = 1.762 | Policy Loss = 0.442 | Steps = 36879 | Walltime = 3258.109
# [Learner] Critic Loss = 1.743 | Policy Loss = 0.445 | Steps = 37636 | Walltime = 3318.164
# [Environment Loop] Episode Length = 1000 | Episode Return = 1598.965087890625 | Episodes = 296 | Steps = 292589 | Steps Per Second = 102.953
# [Learner] Critic Loss = 1.630 | Policy Loss = 0.395 | Steps = 38394 | Walltime = 3378.215
# [Environment Loop] Episode Length = 1000 | Episode Return = 1735.9703369140625 | Episodes = 303 | Steps = 299589 | Steps Per Second = 102.112
# [Learner] Critic Loss = 1.704 | Policy Loss = 0.428 | Steps = 39156 | Walltime = 3438.243
# [Environment Loop] Episode Length = 1000 | Episode Return = 1626.533447265625 | Episodes = 310 | Steps = 306589 | Steps Per Second = 102.562
# [Learner] Critic Loss = 1.684 | Policy Loss = 0.422 | Steps = 39912 | Walltime = 3498.278
# [Environment Loop] Episode Length = 1000 | Episode Return = 1632.7056884765625 | Episodes = 316 | Steps = 312589 | Steps Per Second = 98.588
# [Learner] Critic Loss = 1.673 | Policy Loss = 0.421 | Steps = 40655 | Walltime = 3558.290
# [Environment Loop] Episode Length = 1000 | Episode Return = 1645.8804931640625 | Episodes = 322 | Steps = 318589 | Steps Per Second = 99.894
# INFO:tensorflow:Assets written to: /root/acme/766572c8-085b-11ed-9740-0242ac1c0002/snapshots/policy/assets
# INFO:tensorflow:Assets written to: /root/acme/766572c8-085b-11ed-9740-0242ac1c0002/snapshots/policy/assets
# INFO:tensorflow:Assets written to: /root/acme/766572c8-085b-11ed-9740-0242ac1c0002/snapshots/critic/assets
# INFO:tensorflow:Assets written to: /root/acme/766572c8-085b-11ed-9740-0242ac1c0002/snapshots/critic/assets
# [Learner] Critic Loss = 1.554 | Policy Loss = 0.376 | Steps = 41363 | Walltime = 3618.321
# [Environment Loop] Episode Length = 1000 | Episode Return = 1341.8262939453125 | Episodes = 327 | Steps = 323589 | Steps Per Second = 61.539
# [Learner] Critic Loss = 1.594 | Policy Loss = 0.401 | Steps = 41864 | Walltime = 3678.406
# [Environment Loop] Episode Length = 1000 | Episode Return = 1504.119140625 | Episodes = 332 | Steps = 328589 | Steps Per Second = 97.432
# [Learner] Critic Loss = 1.519 | Policy Loss = 0.383 | Steps = 42542 | Walltime = 3738.466
# [Environment Loop] Episode Length = 1000 | Episode Return = 1507.8485107421875 | Episodes = 338 | Steps = 334589 | Steps Per Second = 95.951
# [Learner] Critic Loss = 1.500 | Policy Loss = 0.402 | Steps = 43269 | Walltime = 3798.524
# [Environment Loop] Episode Length = 1000 | Episode Return = 1472.4146728515625 | Episodes = 344 | Steps = 340589 | Steps Per Second = 94.506
# [Learner] Critic Loss = 1.462 | Policy Loss = 0.377 | Steps = 43974 | Walltime = 3858.570
# [Environment Loop] Episode Length = 1000 | Episode Return = 1355.698974609375 | Episodes = 351 | Steps = 347589 | Steps Per Second = 99.933
# [Learner] Critic Loss = 1.478 | Policy Loss = 0.380 | Steps = 44727 | Walltime = 3918.644
# [Environment Loop] Episode Length = 1000 | Episode Return = 1509.2410888671875 | Episodes = 358 | Steps = 354589 | Steps Per Second = 99.335
# [Learner] Critic Loss = 1.501 | Policy Loss = 0.410 | Steps = 45488 | Walltime = 3978.676
# [Learner] Critic Loss = 1.489 | Policy Loss = 0.386 | Steps = 46248 | Walltime = 4038.691
# [Environment Loop] Episode Length = 1000 | Episode Return = 1583.324951171875 | Episodes = 365 | Steps = 361589 | Steps Per Second = 99.886
# [Learner] Critic Loss = 1.518 | Policy Loss = 0.388 | Steps = 47007 | Walltime = 4098.723
# [Environment Loop] Episode Length = 1000 | Episode Return = 1596.123779296875 | Episodes = 372 | Steps = 368589 | Steps Per Second = 101.378
# [Learner] Critic Loss = 1.532 | Policy Loss = 0.390 | Steps = 47755 | Walltime = 4158.781
# [Environment Loop] Episode Length = 1000 | Episode Return = 1693.73095703125 | Episodes = 378 | Steps = 374589 | Steps Per Second = 102.834
# [Learner] Critic Loss = 1.498 | Policy Loss = 0.401 | Steps = 48518 | Walltime = 4218.842
# [Environment Loop] Episode Length = 1000 | Episode Return = 1507.1002197265625 | Episodes = 385 | Steps = 381589 | Steps Per Second = 103.980
# [Learner] Critic Loss = 1.530 | Policy Loss = 0.419 | Steps = 49287 | Walltime = 4278.913
# [Environment Loop] Episode Length = 1000 | Episode Return = 1564.0780029296875 | Episodes = 392 | Steps = 388589 | Steps Per Second = 102.371
# [Learner] Critic Loss = 1.418 | Policy Loss = 0.363 | Steps = 50047 | Walltime = 4338.951
# [Environment Loop] Episode Length = 1000 | Episode Return = 1686.9285888671875 | Episodes = 399 | Steps = 395589 | Steps Per Second = 102.431
# [Learner] Critic Loss = 1.441 | Policy Loss = 0.389 | Steps = 50822 | Walltime = 4398.979
# [Environment Loop] Episode Length = 1000 | Episode Return = 1591.6480712890625 | Episodes = 406 | Steps = 402589 | Steps Per Second = 101.979
# [Learner] Critic Loss = 1.391 | Policy Loss = 0.347 | Steps = 51603 | Walltime = 4459.018
# [Learner] Critic Loss = 1.416 | Policy Loss = 0.344 | Steps = 52354 | Walltime = 4519.065
# [Environment Loop] Episode Length = 1000 | Episode Return = 1732.478271484375 | Episodes = 413 | Steps = 409589 | Steps Per Second = 91.053
# [Learner] Critic Loss = 1.327 | Policy Loss = 0.344 | Steps = 53060 | Walltime = 4579.085
# [Environment Loop] Episode Length = 1000 | Episode Return = 1656.8343505859375 | Episodes = 419 | Steps = 415589 | Steps Per Second = 102.351
# [Learner] Critic Loss = 1.325 | Policy Loss = 0.358 | Steps = 53799 | Walltime = 4639.152
# [Environment Loop] Episode Length = 1000 | Episode Return = 1715.252197265625 | Episodes = 425 | Steps = 421589 | Steps Per Second = 100.112
# [Learner] Critic Loss = 1.274 | Policy Loss = 0.309 | Steps = 54571 | Walltime = 4699.218
# [Environment Loop] Episode Length = 1000 | Episode Return = 1593.6556396484375 | Episodes = 432 | Steps = 428589 | Steps Per Second = 102.449
# [Learner] Critic Loss = 1.324 | Policy Loss = 0.358 | Steps = 55335 | Walltime = 4759.231
# [Environment Loop] Episode Length = 1000 | Episode Return = 1700.5079345703125 | Episodes = 439 | Steps = 435589 | Steps Per Second = 100.969
# [Learner] Critic Loss = 1.346 | Policy Loss = 0.367 | Steps = 56089 | Walltime = 4819.245
# [Environment Loop] Episode Length = 1000 | Episode Return = 1591.618896484375 | Episodes = 445 | Steps = 441589 | Steps Per Second = 99.047
# [Learner] Critic Loss = 1.227 | Policy Loss = 0.353 | Steps = 56838 | Walltime = 4879.271
# [Environment Loop] Episode Length = 1000 | Episode Return = 1315.4693603515625 | Episodes = 451 | Steps = 447589 | Steps Per Second = 78.993
# [Learner] Critic Loss = 1.201 | Policy Loss = 0.362 | Steps = 57467 | Walltime = 4939.291
# [Environment Loop] Episode Length = 1000 | Episode Return = 1513.6121826171875 | Episodes = 457 | Steps = 453589 | Steps Per Second = 100.857
# [Learner] Critic Loss = 1.275 | Policy Loss = 0.353 | Steps = 58183 | Walltime = 4999.378
# [Environment Loop] Episode Length = 1000 | Episode Return = 1610.021484375 | Episodes = 463 | Steps = 459589 | Steps Per Second = 97.906
# [Learner] Critic Loss = 1.216 | Policy Loss = 0.347 | Steps = 58904 | Walltime = 5059.403
# [Environment Loop] Episode Length = 1000 | Episode Return = 1601.7281494140625 | Episodes = 470 | Steps = 466589 | Steps Per Second = 88.541
# [Learner] Critic Loss = 1.264 | Policy Loss = 0.338 | Steps = 59636 | Walltime = 5119.467
# [Environment Loop] Episode Length = 1000 | Episode Return = 1726.914306640625 | Episodes = 477 | Steps = 473589 | Steps Per Second = 99.198
# [Learner] Critic Loss = 1.206 | Policy Loss = 0.336 | Steps = 60392 | Walltime = 5179.531
# [Learner] Critic Loss = 1.148 | Policy Loss = 0.308 | Steps = 61147 | Walltime = 5239.599
# [Environment Loop] Episode Length = 1000 | Episode Return = 1665.7274169921875 | Episodes = 484 | Steps = 480589 | Steps Per Second = 99.214
# [Learner] Critic Loss = 1.120 | Policy Loss = 0.329 | Steps = 61901 | Walltime = 5299.631
# [Environment Loop] Episode Length = 1000 | Episode Return = 1602.3057861328125 | Episodes = 491 | Steps = 487589 | Steps Per Second = 98.294
# [Learner] Critic Loss = 1.110 | Policy Loss = 0.303 | Steps = 62648 | Walltime = 5359.713
# [Environment Loop] Episode Length = 1000 | Episode Return = 1489.9638671875 | Episodes = 497 | Steps = 493589 | Steps Per Second = 98.985
# INFO:tensorflow:Assets written to: /root/acme/766572c8-085b-11ed-9740-0242ac1c0002/snapshots/policy/assets
# INFO:tensorflow:Assets written to: /root/acme/766572c8-085b-11ed-9740-0242ac1c0002/snapshots/policy/assets
# INFO:tensorflow:Assets written to: /root/acme/766572c8-085b-11ed-9740-0242ac1c0002/snapshots/critic/assets
# INFO:tensorflow:Assets written to: /root/acme/766572c8-085b-11ed-9740-0242ac1c0002/snapshots/critic/assets
# [Learner] Critic Loss = 1.226 | Policy Loss = 0.342 | Steps = 63384 | Walltime = 5419.767
# [Environment Loop] Episode Length = 1000 | Episode Return = 1562.987060546875 | Episodes = 503 | Steps = 499589 | Steps Per Second = 95.720
# [Learner] Critic Loss = 1.133 | Policy Loss = 0.336 | Steps = 64115 | Walltime = 5479.798
# [Environment Loop] Episode Length = 1000 | Episode Return = 1639.8251953125 | Episodes = 509 | Steps = 505589 | Steps Per Second = 101.336
# [Learner] Critic Loss = 1.276 | Policy Loss = 0.357 | Steps = 64865 | Walltime = 5539.855
# [Environment Loop] Episode Length = 1000 | Episode Return = 1683.028564453125 | Episodes = 515 | Steps = 511589 | Steps Per Second = 98.572
# [Learner] Critic Loss = 1.151 | Policy Loss = 0.316 | Steps = 65598 | Walltime = 5599.938
# [Environment Loop] Episode Length = 1000 | Episode Return = 1571.2830810546875 | Episodes = 521 | Steps = 517589 | Steps Per Second = 70.116
# [Learner] Critic Loss = 1.163 | Policy Loss = 0.321 | Steps = 66252 | Walltime = 5659.977
# [Environment Loop] Episode Length = 1000 | Episode Return = 1675.6385498046875 | Episodes = 527 | Steps = 523589 | Steps Per Second = 98.826
# [Learner] Critic Loss = 1.124 | Policy Loss = 0.302 | Steps = 66951 | Walltime = 5720.050
# [Environment Loop] Episode Length = 1000 | Episode Return = 1569.0633544921875 | Episodes = 533 | Steps = 529589 | Steps Per Second = 89.865
# [Learner] Critic Loss = 1.253 | Policy Loss = 0.364 | Steps = 67582 | Walltime = 5780.103
# [Environment Loop] Episode Length = 1000 | Episode Return = 1721.0443115234375 | Episodes = 539 | Steps = 535589 | Steps Per Second = 93.539
# [Learner] Critic Loss = 1.122 | Policy Loss = 0.300 | Steps = 68285 | Walltime = 5840.108
# [Environment Loop] Episode Length = 1000 | Episode Return = 1636.043701171875 | Episodes = 545 | Steps = 541589 | Steps Per Second = 95.227
# [Learner] Critic Loss = 1.128 | Policy Loss = 0.355 | Steps = 68993 | Walltime = 5900.166
# [Environment Loop] Episode Length = 1000 | Episode Return = 1617.017822265625 | Episodes = 551 | Steps = 547589 | Steps Per Second = 98.476
# [Learner] Critic Loss = 1.105 | Policy Loss = 0.314 | Steps = 69719 | Walltime = 5960.240
# [Environment Loop] Episode Length = 1000 | Episode Return = 1667.8770751953125 | Episodes = 557 | Steps = 553589 | Steps Per Second = 94.657
# [Learner] Critic Loss = 1.108 | Policy Loss = 0.322 | Steps = 70438 | Walltime = 6020.357
# [Environment Loop] Episode Length = 1000 | Episode Return = 1634.8880615234375 | Episodes = 562 | Steps = 558589 | Steps Per Second = 90.381
# [Learner] Critic Loss = 1.062 | Policy Loss = 0.316 | Steps = 71047 | Walltime = 6080.420
# [Environment Loop] Episode Length = 1000 | Episode Return = 1577.577880859375 | Episodes = 568 | Steps = 564589 | Steps Per Second = 99.562
# [Learner] Critic Loss = 1.129 | Policy Loss = 0.318 | Steps = 71775 | Walltime = 6140.434
# [Environment Loop] Episode Length = 1000 | Episode Return = 1711.509521484375 | Episodes = 574 | Steps = 570589 | Steps Per Second = 94.534
# [Learner] Critic Loss = 1.101 | Policy Loss = 0.339 | Steps = 72505 | Walltime = 6200.479
# [Environment Loop] Episode Length = 1000 | Episode Return = 1678.383056640625 | Episodes = 580 | Steps = 576589 | Steps Per Second = 97.535
# [Learner] Critic Loss = 1.016 | Policy Loss = 0.299 | Steps = 73233 | Walltime = 6260.504
# [Learner] Critic Loss = 1.036 | Policy Loss = 0.292 | Steps = 73981 | Walltime = 6320.553
# [Environment Loop] Episode Length = 1000 | Episode Return = 1610.1898193359375 | Episodes = 586 | Steps = 582589 | Steps Per Second = 99.328
# [Learner] Critic Loss = 1.009 | Policy Loss = 0.251 | Steps = 74712 | Walltime = 6380.600
# [Environment Loop] Episode Length = 1000 | Episode Return = 1826.6436767578125 | Episodes = 592 | Steps = 588589 | Steps Per Second = 95.930
# [Learner] Critic Loss = 1.040 | Policy Loss = 0.307 | Steps = 75459 | Walltime = 6440.648
# [Environment Loop] Episode Length = 1000 | Episode Return = 1649.258056640625 | Episodes = 598 | Steps = 594589 | Steps Per Second = 97.514
# [Learner] Critic Loss = 1.076 | Policy Loss = 0.322 | Steps = 76190 | Walltime = 6500.707
# [Environment Loop] Episode Length = 1000 | Episode Return = 1730.4290771484375 | Episodes = 604 | Steps = 600589 | Steps Per Second = 95.952
# [Learner] Critic Loss = 0.998 | Policy Loss = 0.277 | Steps = 76885 | Walltime = 6560.735
# [Environment Loop] Episode Length = 1000 | Episode Return = 1712.1287841796875 | Episodes = 610 | Steps = 606589 | Steps Per Second = 97.917
# [Learner] Critic Loss = 1.143 | Policy Loss = 0.340 | Steps = 77559 | Walltime = 6620.801
# [Environment Loop] Episode Length = 1000 | Episode Return = 1700.8905029296875 | Episodes = 616 | Steps = 612589 | Steps Per Second = 96.728
# [Learner] Critic Loss = 1.041 | Policy Loss = 0.298 | Steps = 78226 | Walltime = 6680.845
# [Environment Loop] Episode Length = 1000 | Episode Return = 1616.4554443359375 | Episodes = 622 | Steps = 618589 | Steps Per Second = 84.334
# [Learner] Critic Loss = 1.079 | Policy Loss = 0.282 | Steps = 78885 | Walltime = 6740.882
# [Environment Loop] Episode Length = 1000 | Episode Return = 1587.951416015625 | Episodes = 628 | Steps = 624589 | Steps Per Second = 101.277
# [Learner] Critic Loss = 1.081 | Policy Loss = 0.275 | Steps = 79604 | Walltime = 6800.915
# [Environment Loop] Episode Length = 1000 | Episode Return = 1699.8125 | Episodes = 634 | Steps = 630589 | Steps Per Second = 99.252
# [Learner] Critic Loss = 1.089 | Policy Loss = 0.288 | Steps = 80318 | Walltime = 6860.967
# [Environment Loop] Episode Length = 1000 | Episode Return = 1669.5616455078125 | Episodes = 640 | Steps = 636589 | Steps Per Second = 98.245
# [Learner] Critic Loss = 1.130 | Policy Loss = 0.319 | Steps = 81049 | Walltime = 6921.015
# [Environment Loop] Episode Length = 1000 | Episode Return = 1600.982177734375 | Episodes = 646 | Steps = 642589 | Steps Per Second = 99.812
# [Learner] Critic Loss = 1.028 | Policy Loss = 0.294 | Steps = 81787 | Walltime = 6981.026
# [Environment Loop] Episode Length = 1000 | Episode Return = 1569.095947265625 | Episodes = 652 | Steps = 648589 | Steps Per Second = 96.620
# [Learner] Critic Loss = 1.056 | Policy Loss = 0.291 | Steps = 82532 | Walltime = 7041.095
# [Environment Loop] Episode Length = 1000 | Episode Return = 1594.148681640625 | Episodes = 658 | Steps = 654589 | Steps Per Second = 92.929
# [Learner] Critic Loss = 1.017 | Policy Loss = 0.274 | Steps = 83265 | Walltime = 7101.134
# [Environment Loop] Episode Length = 1000 | Episode Return = 1601.9256591796875 | Episodes = 664 | Steps = 660589 | Steps Per Second = 96.440
# [Learner] Critic Loss = 1.050 | Policy Loss = 0.277 | Steps = 83992 | Walltime = 7161.186
# [Environment Loop] Episode Length = 1000 | Episode Return = 1532.67138671875 | Episodes = 670 | Steps = 666589 | Steps Per Second = 92.192
# INFO:tensorflow:Assets written to: /root/acme/766572c8-085b-11ed-9740-0242ac1c0002/snapshots/policy/assets
# INFO:tensorflow:Assets written to: /root/acme/766572c8-085b-11ed-9740-0242ac1c0002/snapshots/policy/assets
# INFO:tensorflow:Assets written to: /root/acme/766572c8-085b-11ed-9740-0242ac1c0002/snapshots/critic/assets
# INFO:tensorflow:Assets written to: /root/acme/766572c8-085b-11ed-9740-0242ac1c0002/snapshots/critic/assets
# [Learner] Critic Loss = 0.988 | Policy Loss = 0.276 | Steps = 84689 | Walltime = 7221.234
# [Environment Loop] Episode Length = 1000 | Episode Return = 1475.5994873046875 | Episodes = 676 | Steps = 672589 | Steps Per Second = 99.556
# [Learner] Critic Loss = 0.949 | Policy Loss = 0.246 | Steps = 85415 | Walltime = 7281.325
# [Environment Loop] Episode Length = 1000 | Episode Return = 1713.3546142578125 | Episodes = 682 | Steps = 678589 | Steps Per Second = 99.229
# [Learner] Critic Loss = 1.033 | Policy Loss = 0.258 | Steps = 86162 | Walltime = 7341.328
# [Environment Loop] Episode Length = 1000 | Episode Return = 1393.344970703125 | Episodes = 688 | Steps = 684589 | Steps Per Second = 100.616
# [Learner] Critic Loss = 0.936 | Policy Loss = 0.232 | Steps = 86917 | Walltime = 7401.404
# [Environment Loop] Episode Length = 1000 | Episode Return = 1561.5057373046875 | Episodes = 694 | Steps = 690589 | Steps Per Second = 99.831
# [Learner] Critic Loss = 0.988 | Policy Loss = 0.287 | Steps = 87641 | Walltime = 7461.429
# [Environment Loop] Episode Length = 1000 | Episode Return = 1586.513916015625 | Episodes = 700 | Steps = 696589 | Steps Per Second = 96.492
# [Learner] Critic Loss = 0.940 | Policy Loss = 0.272 | Steps = 88354 | Walltime = 7521.464
# [Environment Loop] Episode Length = 1000 | Episode Return = 1595.7569580078125 | Episodes = 704 | Steps = 700589 | Steps Per Second = 50.536
# [Learner] Critic Loss = 0.940 | Policy Loss = 0.250 | Steps = 88765 | Walltime = 7581.485
# [Learner] Critic Loss = 0.955 | Policy Loss = 0.283 | Steps = 89152 | Walltime = 7641.625
# [Environment Loop] Episode Length = 1000 | Episode Return = 1553.512451171875 | Episodes = 708 | Steps = 704589 | Steps Per Second = 43.784
# [Learner] Critic Loss = 0.927 | Policy Loss = 0.259 | Steps = 89497 | Walltime = 7701.628
# [Environment Loop] Episode Length = 1000 | Episode Return = 1700.546630859375 | Episodes = 711 | Steps = 707589 | Steps Per Second = 49.903
# [Learner] Critic Loss = 0.967 | Policy Loss = 0.329 | Steps = 89878 | Walltime = 7761.719
# [Environment Loop] Episode Length = 1000 | Episode Return = 1600.402587890625 | Episodes = 715 | Steps = 711589 | Steps Per Second = 53.975
# [Learner] Critic Loss = 0.929 | Policy Loss = 0.253 | Steps = 90281 | Walltime = 7821.809
# [Environment Loop] Episode Length = 1000 | Episode Return = 1615.795166015625 | Episodes = 719 | Steps = 715589 | Steps Per Second = 77.172
# [Learner] Critic Loss = 1.011 | Policy Loss = 0.282 | Steps = 90822 | Walltime = 7881.879
# [Environment Loop] Episode Length = 1000 | Episode Return = 1583.2471923828125 | Episodes = 724 | Steps = 720589 | Steps Per Second = 84.525
# [Learner] Critic Loss = 1.023 | Policy Loss = 0.292 | Steps = 91450 | Walltime = 7941.890
# [Environment Loop] Episode Length = 1000 | Episode Return = 1645.34912109375 | Episodes = 730 | Steps = 726589 | Steps Per Second = 90.736
# [Learner] Critic Loss = 1.030 | Policy Loss = 0.343 | Steps = 92123 | Walltime = 8001.926
# [Environment Loop] Episode Length = 1000 | Episode Return = 1633.7960205078125 | Episodes = 736 | Steps = 732589 | Steps Per Second = 95.949
# [Learner] Critic Loss = 1.036 | Policy Loss = 0.296 | Steps = 92829 | Walltime = 8061.955
# [Environment Loop] Episode Length = 1000 | Episode Return = 1587.5408935546875 | Episodes = 742 | Steps = 738589 | Steps Per Second = 99.635
# [Learner] Critic Loss = 1.027 | Policy Loss = 0.284 | Steps = 93579 | Walltime = 8122.023
# [Learner] Critic Loss = 0.947 | Policy Loss = 0.274 | Steps = 94345 | Walltime = 8182.040
# [Environment Loop] Episode Length = 1000 | Episode Return = 1728.4061279296875 | Episodes = 749 | Steps = 745589 | Steps Per Second = 102.933
# [Learner] Critic Loss = 0.918 | Policy Loss = 0.292 | Steps = 95114 | Walltime = 8242.057
# [Environment Loop] Episode Length = 1000 | Episode Return = 1538.7647705078125 | Episodes = 756 | Steps = 752589 | Steps Per Second = 102.987
# [Learner] Critic Loss = 0.986 | Policy Loss = 0.283 | Steps = 95893 | Walltime = 8302.061
# [Environment Loop] Episode Length = 1000 | Episode Return = 1563.18994140625 | Episodes = 763 | Steps = 759589 | Steps Per Second = 104.350
# [Learner] Critic Loss = 0.994 | Policy Loss = 0.325 | Steps = 96668 | Walltime = 8362.125
# [Environment Loop] Episode Length = 1000 | Episode Return = 1689.394775390625 | Episodes = 770 | Steps = 766589 | Steps Per Second = 102.920
# [Learner] Critic Loss = 0.880 | Policy Loss = 0.263 | Steps = 97437 | Walltime = 8422.172
# [Environment Loop] Episode Length = 1000 | Episode Return = 1598.7388916015625 | Episodes = 777 | Steps = 773589 | Steps Per Second = 102.258
# [Learner] Critic Loss = 0.928 | Policy Loss = 0.257 | Steps = 98211 | Walltime = 8482.198
# [Environment Loop] Episode Length = 1000 | Episode Return = 1602.4456787109375 | Episodes = 783 | Steps = 779589 | Steps Per Second = 100.968
# [Learner] Critic Loss = 0.961 | Policy Loss = 0.254 | Steps = 98931 | Walltime = 8542.231
# [Environment Loop] Episode Length = 1000 | Episode Return = 1521.82275390625 | Episodes = 790 | Steps = 786589 | Steps Per Second = 100.285
# [Learner] Critic Loss = 0.980 | Policy Loss = 0.282 | Steps = 99682 | Walltime = 8602.239
# [Environment Loop] Episode Length = 1000 | Episode Return = 1093.7696533203125 | Episodes = 796 | Steps = 792589 | Steps Per Second = 99.411
# [Learner] Critic Loss = 0.816 | Policy Loss = 0.253 | Steps = 100425 | Walltime = 8662.276
# [Environment Loop] Episode Length = 1000 | Episode Return = 1568.9969482421875 | Episodes = 803 | Steps = 799589 | Steps Per Second = 100.415
# [Learner] Critic Loss = 0.940 | Policy Loss = 0.258 | Steps = 101185 | Walltime = 8722.344
# [Environment Loop] Episode Length = 1000 | Episode Return = 1631.60986328125 | Episodes = 809 | Steps = 805589 | Steps Per Second = 79.848
# [Learner] Critic Loss = 0.970 | Policy Loss = 0.271 | Steps = 101873 | Walltime = 8782.452
# [Learner] Critic Loss = 0.801 | Policy Loss = 0.239 | Steps = 102525 | Walltime = 8842.479
# [Environment Loop] Episode Length = 1000 | Episode Return = 1630.0301513671875 | Episodes = 815 | Steps = 811589 | Steps Per Second = 94.363
# [Learner] Critic Loss = 0.967 | Policy Loss = 0.286 | Steps = 103227 | Walltime = 8902.557
# [Environment Loop] Episode Length = 1000 | Episode Return = 1605.2772216796875 | Episodes = 821 | Steps = 817589 | Steps Per Second = 99.954
# [Learner] Critic Loss = 0.863 | Policy Loss = 0.255 | Steps = 103929 | Walltime = 8962.643
# [Environment Loop] Episode Length = 1000 | Episode Return = 1511.330078125 | Episodes = 827 | Steps = 823589 | Steps Per Second = 94.696
# INFO:tensorflow:Assets written to: /root/acme/766572c8-085b-11ed-9740-0242ac1c0002/snapshots/policy/assets
# INFO:tensorflow:Assets written to: /root/acme/766572c8-085b-11ed-9740-0242ac1c0002/snapshots/policy/assets
# INFO:tensorflow:Assets written to: /root/acme/766572c8-085b-11ed-9740-0242ac1c0002/snapshots/critic/assets
# INFO:tensorflow:Assets written to: /root/acme/766572c8-085b-11ed-9740-0242ac1c0002/snapshots/critic/assets
# [Learner] Critic Loss = 0.961 | Policy Loss = 0.267 | Steps = 104536 | Walltime = 9022.649
# [Environment Loop] Episode Length = 1000 | Episode Return = 1520.1246337890625 | Episodes = 832 | Steps = 828589 | Steps Per Second = 82.094
# [Learner] Critic Loss = 0.872 | Policy Loss = 0.236 | Steps = 105217 | Walltime = 9082.655
# [Environment Loop] Episode Length = 1000 | Episode Return = 1467.0633544921875 | Episodes = 838 | Steps = 834589 | Steps Per Second = 95.313
# [Learner] Critic Loss = 0.873 | Policy Loss = 0.269 | Steps = 105927 | Walltime = 9142.678
# [Environment Loop] Episode Length = 1000 | Episode Return = 1481.429443359375 | Episodes = 844 | Steps = 840589 | Steps Per Second = 101.037
# [Learner] Critic Loss = 0.905 | Policy Loss = 0.277 | Steps = 106668 | Walltime = 9202.701
# [Environment Loop] Episode Length = 1000 | Episode Return = 1329.4344482421875 | Episodes = 850 | Steps = 846589 | Steps Per Second = 89.328
# [Learner] Critic Loss = 0.928 | Policy Loss = 0.269 | Steps = 107371 | Walltime = 9262.751
# [Environment Loop] Episode Length = 1000 | Episode Return = 1638.2696533203125 | Episodes = 856 | Steps = 852589 | Steps Per Second = 101.420
# [Learner] Critic Loss = 0.978 | Policy Loss = 0.263 | Steps = 108120 | Walltime = 9322.788
# [Environment Loop] Episode Length = 1000 | Episode Return = 1570.396484375 | Episodes = 862 | Steps = 858589 | Steps Per Second = 98.591
# [Learner] Critic Loss = 0.884 | Policy Loss = 0.256 | Steps = 108865 | Walltime = 9382.832
# [Environment Loop] Episode Length = 1000 | Episode Return = 1599.4876708984375 | Episodes = 869 | Steps = 865589 | Steps Per Second = 103.750
# [Learner] Critic Loss = 0.888 | Policy Loss = 0.278 | Steps = 109631 | Walltime = 9442.852
# [Environment Loop] Episode Length = 1000 | Episode Return = 1601.1707763671875 | Episodes = 876 | Steps = 872589 | Steps Per Second = 103.417
# [Learner] Critic Loss = 0.841 | Policy Loss = 0.230 | Steps = 110398 | Walltime = 9502.863
# [Environment Loop] Episode Length = 1000 | Episode Return = 1564.391845703125 | Episodes = 883 | Steps = 879589 | Steps Per Second = 104.520
# [Learner] Critic Loss = 0.835 | Policy Loss = 0.283 | Steps = 111173 | Walltime = 9562.899
# [Learner] Critic Loss = 0.867 | Policy Loss = 0.261 | Steps = 111938 | Walltime = 9622.940
# [Environment Loop] Episode Length = 1000 | Episode Return = 1296.3321533203125 | Episodes = 890 | Steps = 886589 | Steps Per Second = 99.385
# [Learner] Critic Loss = 0.888 | Policy Loss = 0.248 | Steps = 112677 | Walltime = 9683.016
# [Environment Loop] Episode Length = 1000 | Episode Return = 1609.5177001953125 | Episodes = 896 | Steps = 892589 | Steps Per Second = 96.807
# [Learner] Critic Loss = 0.946 | Policy Loss = 0.276 | Steps = 113364 | Walltime = 9743.072
# [Environment Loop] Episode Length = 1000 | Episode Return = 1437.59716796875 | Episodes = 902 | Steps = 898589 | Steps Per Second = 98.522
# [Learner] Critic Loss = 0.957 | Policy Loss = 0.274 | Steps = 114084 | Walltime = 9803.073
# [Environment Loop] Episode Length = 1000 | Episode Return = 1687.531982421875 | Episodes = 908 | Steps = 904589 | Steps Per Second = 94.026
# [Learner] Critic Loss = 1.031 | Policy Loss = 0.291 | Steps = 114714 | Walltime = 9863.113
# [Environment Loop] Episode Length = 1000 | Episode Return = 1603.9661865234375 | Episodes = 913 | Steps = 909589 | Steps Per Second = 87.457
# [Learner] Critic Loss = 0.850 | Policy Loss = 0.258 | Steps = 115445 | Walltime = 9923.185
# [Environment Loop] Episode Length = 1000 | Episode Return = 1662.0120849609375 | Episodes = 920 | Steps = 916589 | Steps Per Second = 102.762
# [Learner] Critic Loss = 0.950 | Policy Loss = 0.281 | Steps = 116225 | Walltime = 9983.244
# [Environment Loop] Episode Length = 1000 | Episode Return = 1594.9068603515625 | Episodes = 927 | Steps = 923589 | Steps Per Second = 106.207
# [Learner] Critic Loss = 0.776 | Policy Loss = 0.240 | Steps = 117028 | Walltime = 10043.263
# [Environment Loop] Episode Length = 1000 | Episode Return = 1695.3564453125 | Episodes = 934 | Steps = 930589 | Steps Per Second = 105.425
# [Learner] Critic Loss = 0.824 | Policy Loss = 0.274 | Steps = 117825 | Walltime = 10103.312
# [Environment Loop] Episode Length = 1000 | Episode Return = 1616.666259765625 | Episodes = 941 | Steps = 937589 | Steps Per Second = 107.191
# [Learner] Critic Loss = 0.922 | Policy Loss = 0.288 | Steps = 118616 | Walltime = 10163.382
# [Environment Loop] Episode Length = 1000 | Episode Return = 1580.9068603515625 | Episodes = 948 | Steps = 944589 | Steps Per Second = 103.289
# [Learner] Critic Loss = 0.781 | Policy Loss = 0.252 | Steps = 119409 | Walltime = 10223.448
# [Environment Loop] Episode Length = 1000 | Episode Return = 1553.514404296875 | Episodes = 955 | Steps = 951589 | Steps Per Second = 107.042
# [Learner] Critic Loss = 0.824 | Policy Loss = 0.235 | Steps = 120195 | Walltime = 10283.465
# [Environment Loop] Episode Length = 1000 | Episode Return = 1532.9393310546875 | Episodes = 962 | Steps = 958589 | Steps Per Second = 107.837
# [Learner] Critic Loss = 0.903 | Policy Loss = 0.299 | Steps = 121003 | Walltime = 10343.506
# [Learner] Critic Loss = 0.853 | Policy Loss = 0.268 | Steps = 121809 | Walltime = 10403.539
# [Environment Loop] Episode Length = 1000 | Episode Return = 1506.8389892578125 | Episodes = 969 | Steps = 965589 | Steps Per Second = 109.445
# [Learner] Critic Loss = 0.874 | Policy Loss = 0.272 | Steps = 122626 | Walltime = 10463.579
# [Environment Loop] Episode Length = 1000 | Episode Return = 1494.4249267578125 | Episodes = 976 | Steps = 972589 | Steps Per Second = 106.819
# [Learner] Critic Loss = 0.809 | Policy Loss = 0.248 | Steps = 123422 | Walltime = 10523.643
# [Environment Loop] Episode Length = 1000 | Episode Return = 1623.4935302734375 | Episodes = 983 | Steps = 979589 | Steps Per Second = 104.018
# [Learner] Critic Loss = 0.915 | Policy Loss = 0.257 | Steps = 124202 | Walltime = 10583.649
# [Environment Loop] Episode Length = 1000 | Episode Return = 1655.61279296875 | Episodes = 990 | Steps = 986589 | Steps Per Second = 106.820
# [Learner] Critic Loss = 0.789 | Policy Loss = 0.243 | Steps = 124979 | Walltime = 10643.689
# [Environment Loop] Episode Length = 1000 | Episode Return = 1649.0321044921875 | Episodes = 997 | Steps = 993589 | Steps Per Second = 99.500
# [Learner] Critic Loss = 0.746 | Policy Loss = 0.235 | Steps = 125726 | Walltime = 10703.744
# [Environment Loop] Episode Length = 1000 | Episode Return = 1540.9036865234375 | Episodes = 1003 | Steps = 999589 | Steps Per Second = 98.854

# %% [markdown]
# ## Examine trained policy
#
# As the policy has (hopefully) been trained by now, let's test it in the environment and examine the result.
#
# Note that we will also collect the reward at each timestep and plot it later.

# %%
# Run the environment with the learned policy and display video.
n_steps = 500

frames = []  # Frames for video.
reward = [[]]  # Reward at every timestep.
timestep = env.reset()
for _ in range(n_steps):
  frames.append(env.environment.render(mode='rgb_array').copy())
  action = agent.select_action(timestep.observation)
  timestep = env.step(action)

  # `timestep.reward` is None when episode terminates.
  if timestep.reward:
    # Old episode continues.
    reward[-1].append(timestep.reward.item())
  else:
    # New episode begins.
    reward.append([])

display_video(frames)
# Out:
# <video width="320" height="240" controls autoplay>
#   <source type="video/mp4" src="...

# %% [markdown]
# ## Plot the reward
#
# Each color represent a separate episode.

# %%
env_step = 0
for episode in reward:
  plt.plot(np.arange(env_step, env_step+len(episode)), episode)
  env_step += len(episode)
plt.xlabel('Timestep', fontsize=14)
plt.ylabel('Reward', fontsize=14)
plt.grid()
plt.show()

# %% [markdown]
# ## Total reward
#
# Finally, let's print the total reward for the test episodes

# %%
for i, episode in enumerate(reward):
  print(f"Total reward in episode {i}: {sum(episode):.2f}")
# Out:
# Total reward in episode 0: 829.27

# %% [markdown]
# ## Saving and restoring training checkpoints to/from Google Drive
#
# To avoid losing the training checkpoints during runtime restart, follow these steps:

# %% [markdown]
# ### 1. Mount drive to temporarily save checkpoints

# %%
# Mount drive. -- You may want to add your gDrive
# drive.mount('/root/drive')

# %% [markdown]
# ### 2. BEFORE restarting the runtime, save checkpoint to drive

# %%
# Save agent checkpoint to drive.
save_ckpt_to_drive(agent)
# Out:
# Saved /root/acme/456444d4-035f-11ed-86f6-0242ac1c0002/checkpoints/d4pg_learner to /root/drive/MyDrive/acme_ckpt

# %% [markdown]
# ### 3. AFTER restarting the runtime, restore checkpoint from drive
#
# To restore a checkpoint in the restarted Colab runtime:
#
# 1.   Re-install all the libraries and run all the cells as before, including the agent instantiation, **except** the training cell.
# 2.   Run the cell below.
# 3.   Run the cell that instantiates the agent **again**.

# %%
# Restore checkpoint from drive.
restore_ckpt_from_drive(agent)
# Out:
# Restored /root/acme/456444d4-035f-11ed-86f6-0242ac1c0002/checkpoints/d4pg_learner from /root/drive/MyDrive/acme_ckpt

# %% [markdown]
# ### 4. Optionally, unmount drive

# %%
# Unmount drive.
drive.flush_and_unmount()
# Out:
# Drive not mounted, so nothing to flush and unmount.

# %% [markdown]
# ---
# # Examples of two additional agents:

# %% [markdown]
# ## DMPO agent

# %%
# Create networks.
policy_network, critic_network = make_networks_dmpo(action_spec)

# Create agent.
agent = DistributionalMPO(environment_spec=env_spec,
                          policy_network=policy_network,
                          critic_network=critic_network,
                          observation_network=tf2_utils.batch_concat,
                          policy_optimizer=policy_optimizer,
                          critic_optimizer=critic_optimizer,
                          logger=learner_logger,
                          checkpoint=False)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_probability/python/distributions/distribution.py:342: calling Independent.__init__ (from tensorflow_probability.python.distributions.independent) with reinterpreted_batch_ndims=None is deprecated and will be removed after 2022-03-01.
# Instructions for updating:
# Please pass an integer value for `reinterpreted_batch_ndims`. The current behavior corresponds to `reinterpreted_batch_ndims=tf.size(distribution.batch_shape_tensor()) - 1`.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_probability/python/distributions/distribution.py:342: calling Independent.__init__ (from tensorflow_probability.python.distributions.independent) with reinterpreted_batch_ndims=None is deprecated and will be removed after 2022-03-01.
# Instructions for updating:
# Please pass an integer value for `reinterpreted_batch_ndims`. The current behavior corresponds to `reinterpreted_batch_ndims=tf.size(distribution.batch_shape_tensor()) - 1`.

# %% [markdown]
# ## DDPG agent

# %%
# Create networks.
policy_network, critic_network = make_networks_ddpg(action_spec)

# Create agent.
agent = DDPG(environment_spec=env_spec,
             policy_network=policy_network,
             critic_network=critic_network,
             observation_network= tf2_utils.batch_concat, # Identity Op.
             logger=learner_logger,
             checkpoint=checkpoint)

# %% [markdown]
# ---
# # Good luck :)
